# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pylab as pl
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/kp473/Downloads/DATA_BYTE_1/company_sales_data - company_sales_data.csv")

# %%
print(df.head())
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
print(len(df.total_profit))
# Out:
# 12

# %%
plt.plot(df.month_number,df.total_profit,'red')
plt.xlabel('Month',color='blue')
plt.ylabel('Profit',color='blue')
plt.title('Company Sales',color='blue')
plt.grid()

# %%
plt.rcParams["figure.figsize"] = (12,7)
fig, ax = plt.subplots()
ax.plot(df.month_number, df.facecream, label='facecream') 
ax.plot(df.month_number, df.facewash, label='facewash')
ax.plot(df.month_number, df.toothpaste, label='toothpaste')
ax.plot(df.month_number, df.bathingsoap, label='bathingsoap')
ax.plot(df.month_number, df.shampoo, label='shampoo')
ax.plot(df.month_number, df.moisturizer, label='moisturizer')

ax.set_xlabel('Month',fontsize=20, color='blue') 
ax.set_ylabel('Total Sales',fontsize=20,color='blue') 
ax.set_title("Company_Data_Sales",fontsize=20,color='blue') 
ax.legend()

# %%
df.total_profit
# Out:
# 0     211000
# 1     183300
# 2     224700
# 3     222700
# 4     209600
# 5     201400
# 6     295500
# 7     361400
# 8     234000
# 9     266700
# 10    412800
# 11    300200
# Name: total_profit, dtype: int64

# %%
sales=[]
a=0
for row in df.loc[:,"facecream"]:
    a += row
sales.append(a)
a=0
for row in df.loc[:,"facewash"]:
    a+= row
sales.append(a)
a=0
for row in df.loc[:,"toothpaste"]:
    a+= row
sales.append(a)
a=0
for row in df.loc[:,"bathingsoap"]:
    a+= row
sales.append(a)
a=0
for row in df.loc[:,"shampoo"]:
    a+= row
sales.append(a)
a=0
for row in df.loc[:,"moisturizer"]:
    a+= row
sales.append(a)
print(sales)
# Out:
# [34480, 18515, 69910, 114010, 25410, 18515]

# %%
index=df.columns.values
a=list(index)
a=a[1:7]
print(a)
# Out:
# ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']

# %%
plt.pie(x=sales, labels=a, radius=1, autopct= '%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e21b621bc8>,
# ...
#  [Text(1.0191857113582774, 0.4138363030995739, 'facecream'),
#   Text(0.6140655913722997, 0.912646398936953, 'facewash'),
#   Text(-0.4252111998343268, 1.0144926986112084, 'toothpaste'),
#   Text(-0.6978920809686103, -0.8502626907734472, 'bathingsoap'),
#   Text(0.8424027164269658, -0.7073596421598204, 'shampoo'),
#   Text(1.0764907254787095, -0.226202824823922, 'moisturizer')],
#  [Text(0.5559194789226967, 0.22572889259976756, '12.28%'),
#   Text(0.3349448680212543, 0.4978071266928834, '6.59%'),
#   Text(-0.2319333817278146, 0.5533596537879318, '24.89%'),
#   Text(-0.38066840780106015, -0.4637796495127893, '40.60%'),
#   Text(0.459492390778345, -0.3858325320871747, '9.05%'),
#   Text(0.5871767593520233, -0.12338335899486653, '6.59%')])
